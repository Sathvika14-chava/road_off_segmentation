# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Hackthon_project
# Out:
# /content/drive/MyDrive/Hackthon_project

# %%
# !ls
# Out:
# Offroad_Segmentation_Scripts	 Offroad_Segmentation_Training_Dataset
# Offroad_Segmentation_testImages

# %%
# !ls train
# Out:
# ls: cannot access 'train': No such file or directory

# %%
# %cd /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Scripts
# Out:
# /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Scripts

# %%
# !ls
# Out:
# ENV_SETUP    segmentation_head.pth  train_segmentation.py  visualize.py
# predictions  test_segmentation.py   train_stats

# %%
# !pip install torch torchvision opencv-python matplotlib

# %%
# !python train_segmentation.py
# Out:
# Using device: cuda
# Training samples: 46
# Validation samples: 46
# Loading DINOv2 backbone...
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vits14/dinov2_vits14_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vits14_pretrain.pth
# 100% 84.2M/84.2M [00:00<00:00, 561MB/s]
# ...

# %%
# !ls /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/Offroad_Segmentation_Training_Dataset/train

# %%
# !python Segmentation.py

# %%
# !mv /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/train/Segmentation \
/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/train/Labels

# %%
# !sed -i 's/Labels/Segmentation/g' train_segmentation.py

# %%
# !sed -i "s|data_dir = .*|data_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset'|g" train_segmentation.py

# %%
# !sed -i "s|data_dir = .*|data_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/train'|g" train_segmentation.py

# %%
# !python train_segmentation.py

# %%
# !ls /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset

# %%
# !ls /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/train

# %%
# !ls /content/drive/MyDrive

# %%
# !ls /content/drive/MyDrive/Hackthon_project

# %%
# !sed -i "s|self.image_dir = .*|self.image_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/train/Color_Images'|g" Offroad_Segmentation_Scripts/train_segmentation.py

# %%
# %cd /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Scripts

# %%
# !ls

# %%
# !sed -i "s|self.image_dir = .*|self.image_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/train/Color_Images'|g" train_segmentation.py

# %%
# !sed -i "s|self.mask_dir = .*|self.mask_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/train/Segmentation'|g" train_segmentation.py

# %%
# !python train_segmentation.py

# %%
# !ls /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/train

# %%
# %cd /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Scripts

# %%
# !sed -i "s|self.image_dir = .*|self.image_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/Color_Images'|g" train_segmentation.py

# %%
# !sed -i "s|self.mask_dir = .*|self.mask_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/Segmentation'|g" train_segmentation.py

# %%
# !python train_segmentation.py

# %%
# !ls /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset

# %%
# !ls /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/

# %%
# !sed -i "s|self.image_dir = .*|self.image_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/Offroad_Segmentation_Training_Dataset/Color_Images'|g" train_segmentation.py

# %%
# !sed -i "s|self.mask_dir = .*|self.mask_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/Offroad_Segmentation_Training_Dataset/Segmentation'|g" train_segmentation.py

# %%
# !python train_segmentation.py

# %%
# !mv /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/Offroad_Segmentation_Training_Dataset/* \
/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/

# %%
# !python train_segmentation.py

# %%
# %cd /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Scripts

# %%
# !sed -i "s|self.image_dir = .*|self.image_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/Offroad_Segmentation_Training_Dataset/Color_Images'|g" train_segmentation.py

# %%
# !sed -i "s|self.mask_dir = .*|self.mask_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/Offroad_Segmentation_Training_Dataset/Segmentation'|g" train_segmentation.py

# %%
# !sed -i "s|data_dir = .*|data_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/Offroad_Segmentation_Training_Dataset'|g" train_segmentation.py

# %%
# !python train_segmentation.py

# %%
# !ls /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Training_Dataset/Offroad_Segmentation_Training_Dataset

# %%
# !ls -R /content/drive/MyDrive/Hackthon_project

# %%
# %cd /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Scripts

# %%
# !sed -i "s|self.image_dir = .*|self.image_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_testImages/Offroad_Segmentation_testImages/Color_Images'|g" train_segmentation.py

# %%
# !sed -i "s|self.mask_dir = .*|self.mask_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_testImages/Offroad_Segmentation_testImages/Segmentation'|g" train_segmentation.py

# %%
# !python train_segmentation.py

# %%
# !sed -i "s|Offroad_Segmentation_Training_Dataset/Offroad_Segmentation_Training_Dataset/Segmentation|Offroad_Segmentation_testImages/Offroad_Segmentation_testImages/Segmentation|g" train_segmentation.py

# %%
# !python train_segmentation.py

# %%
# !sed -i "s|Offroad_Segmentation_Training_Dataset/Offroad_Segmentation_Training_Dataset|Offroad_Segmentation_testImages/Offroad_Segmentation_testImages|g" train_segmentation.py

# %%
# !sed -i "s|self.image_dir = .*|self.image_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_testImages/Offroad_Segmentation_testImages/Color_Images'|g" train_segmentation.py

# %%
# !sed -i "s|self.mask_dir = .*|self.mask_dir = '/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_testImages/Offroad_Segmentation_testImages/Segmentation'|g" train_segmentation.py

# %%
trainset = MaskDataset(data_dir=data_dir, transform=transform, mask_transform=mask_transform)
train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True)

valset = MaskDataset(data_dir=val_dir, transform=transform, mask_transform=mask_transform)
val_loader = DataLoader(valset, batch_size=batch_size, shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_24176/1293400640.py in <cell line: 0>()
# ----> 1 trainset = MaskDataset(data_dir=data_dir, transform=transform, mask_transform=mask_transform)
#       2 train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True)
#       3
#       4 valset = MaskDataset(data_dir=val_dir, transform=transform, mask_transform=mask_transform)
#       5 val_loader = DataLoader(valset, batch_size=batch_size, shuffle=False)
#
# NameError: name 'MaskDataset' is not defined

# %%
# !python train_segmentation.py

# %%
# !sed -i "s|val_loader|train_loader|g" train_segmentation.py

# %%
# !python train_segmentation.py
# Out:
# Using device: cuda
# Training samples: 46
# Validation samples: 46
# Loading DINOv2 backbone...
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Backbone loaded successfully!
# Embedding dimension: 384
# Patch tokens shape: torch.Size([2, 646, 384])
#
# Starting training...
# ...
# Training:   0% 0/50 [00:00<?, ?epoch/s]
# Epoch 1/50 [Train]:   0% 0/23 [00:00<?, ?batch/s]
# ...

# %%
# !sed -i "s|Offroad_Segmentation_Training_Dataset/val|Offroad_Segmentation_testImages/Offroad_Segmentation_testImages|g" train_segmentation.py

# %%
# !sed -i "s|valset = MaskDataset.*|valset = trainset|g" train_segmentation.py

# %%
# !python train_segmentation.py

# %%
# !python test_segmentation.py

# %%
# !sed -i "s|Offroad_Segmentation_testImages|Offroad_Segmentation_testImages/Offroad_Segmentation_testImages|g" test_segmentation.py

# %%
# !python test_segmentation.py

# %%
# !ls /content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Scripts/predictions/comparisons

# %%
from IPython.display import Image, display
import os

folder = "/content/drive/MyDrive/Hackthon_project/Offroad_Segmentation_Scripts/predictions/comparisons"

files = os.listdir(folder)

for f in files[:5]:   # shows first 5 images
    display(Image(os.path.join(folder, f)))
